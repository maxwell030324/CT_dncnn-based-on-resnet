# %%
import tensorflow as tf
import train_config

tf.config.experimental_run_functions_eagerly(True)

# L1 Loss
def l1_loss(y_true, y_pred):
    # 计算L1 Loss
    l1 = tf.keras.losses.mean_absolute_error(y_true, y_pred)
    return l1

if __name__ == "__main__":
    

    
    # --------------------model 2_1--------------------
    
    opt = tf.keras.optimizers.Adam(1e-3)
    train_config.train(
       beta=0.35,
       train_dir_name="train",
       isreload=False,
       reload_path=None,
       opt=opt,
       model_path = "/home/mist/Project/model2_1/dncnn2_1",
       log_path="/home/mist/Project/log/dncnn2_1",
       Epochs=8,
       Batch_Size=5,
       loss_func=l1_loss)

# %%
import tensorflow as tf
import train_config

tf.config.experimental_run_functions_eagerly(True)

# L1 Loss
def l1_loss(y_true, y_pred):
    # 计算L1 Loss
    l1 = tf.keras.losses.mean_absolute_error(y_true, y_pred)
    return l1

if __name__ == "__main__":
    

    
    # --------------------model 2_2--------------------
    
    opt = tf.keras.optimizers.Adam(1e-3)
    train_config.train(
       beta=0.35,
       train_dir_name="train",
       isreload=True,
       reload_path="/home/mist/Project/model2_1",
       opt=opt,
       model_path = "/home/mist/Project/model2_2/dncnn2_2",
       log_path="/home/mist/Project/log/dncnn2_2",
       Epochs=8,
       Batch_Size=5,
       loss_func=l1_loss)

# %%
import tensorflow as tf
import train_config

tf.config.experimental_run_functions_eagerly(True)

# L1 Loss
def l1_loss(y_true, y_pred):
    # 计算L1 Loss
    l1 = tf.keras.losses.mean_absolute_error(y_true, y_pred)
    return l1

if __name__ == "__main__":
    

    
    # --------------------model 2_3--------------------
    
    opt = tf.keras.optimizers.Adam(1e-3)
    train_config.train(
       beta=0.35,
       train_dir_name="train",
       isreload=True,
       reload_path="/home/mist/Project/model2_2",
       opt=opt,
       model_path = "/home/mist/Project/model2_3/dncnn2_3",
       log_path="/home/mist/Project/log/dncnn2_3",
       Epochs=20,
       Batch_Size=5,
       loss_func=l1_loss)

# %%
import tensorflow as tf
import train_config

tf.config.experimental_run_functions_eagerly(True)

# L1 Loss
def l1_loss(y_true, y_pred):
    # 计算L1 Loss
    l1 = tf.keras.losses.mean_absolute_error(y_true, y_pred)
    return l1

if __name__ == "__main__":
    

    
    # --------------------model 2_4--------------------
    
    opt = tf.keras.optimizers.Adam(1e-3)
    train_config.train(
       beta=0.35,
       train_dir_name="train",
       isreload=True,
       reload_path="/home/mist/Project/model2_3",
       opt=opt,
       model_path = "/home/mist/Project/model2_4/dncnn2_4",
       log_path="/home/mist/Project/log/dncnn2_4",
       Epochs=20,
       Batch_Size=5,
       loss_func=l1_loss)
# Out:
# 4551/4551 [==============================] - 690s 151ms/step - loss: 0.0146 - accuracy: 0.3267 - val_loss: 0.0140 - val_accuracy: 0.2562
# Epoch 2/20
# 4551/4551 [==============================] - 685s 151ms/step - loss: 0.0146 - accuracy: 0.3267 - val_loss: 0.0141 - val_accuracy: 0.2562
# Epoch 3/20
# 4551/4551 [==============================] - 687s 151ms/step - loss: 0.0146 - accuracy: 0.3267 - val_loss: 0.0152 - val_accuracy: 0.2562
# Epoch 4/20
# 4551/4551 [==============================] - 686s 151ms/step - loss: 0.0145 - accuracy: 0.3267 - val_loss: 0.0138 - val_accuracy: 0.2562
# Epoch 5/20
# 4551/4551 [==============================] - 686s 151ms/step - loss: 0.0145 - accuracy: 0.3267 - val_loss: 0.0139 - val_accuracy: 0.2562
# Epoch 6/20
# 4551/4551 [==============================] - 686s 151ms/step - loss: 0.0145 - accuracy: 0.3267 - val_loss: 0.0137 - val_accuracy: 0.2562
# Epoch 7/20
# ...

# %%
import tensorflow as tf
import train_config

tf.config.experimental_run_functions_eagerly(True)

# L1 Loss
def l1_loss(y_true, y_pred):
    # 计算L1 Loss
    l1 = tf.keras.losses.mean_absolute_error(y_true, y_pred)
    return l1

if __name__ == "__main__":
    

    
    # --------------------model 2_5--------------------
    
    opt = tf.keras.optimizers.Adam(1e-3)
    train_config.train(
       beta=0.35,
       train_dir_name="train",
       isreload=True,
       reload_path="/home/mist/Project/model2_4",
       opt=opt,
       model_path = "/home/mist/Project/model2_5/dncnn2_5",
       log_path="/home/mist/Project/log/dncnn2_5",
       Epochs=14,
       Batch_Size=5,
       loss_func=l1_loss)
# Out:
# Epoch 1/14
# 2023-12-21 12:29:01.254344: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8400
# 4551/4551 [==============================] - 686s 150ms/step - loss: 0.0143 - accuracy: 0.3267 - val_loss: 0.0132 - val_accuracy: 0.2562
# Epoch 2/14
# 4551/4551 [==============================] - 679s 149ms/step - loss: 0.0143 - accuracy: 0.3267 - val_loss: 0.0140 - val_accuracy: 0.2562
# Epoch 3/14
# 4551/4551 [==============================] - 684s 150ms/step - loss: 0.0143 - accuracy: 0.3267 - val_loss: 0.0133 - val_accuracy: 0.2562
# Epoch 4/14
# 4551/4551 [==============================] - 683s 150ms/step - loss: 0.0143 - accuracy: 0.3267 - val_loss: 0.0136 - val_accuracy: 0.2562
# Epoch 5/14
# 4551/4551 [==============================] - 682s 150ms/step - loss: 0.0143 - accuracy: 0.3267 - val_loss: 0.0136 - val_accuracy: 0.2562
# Epoch 6/14
# ...
